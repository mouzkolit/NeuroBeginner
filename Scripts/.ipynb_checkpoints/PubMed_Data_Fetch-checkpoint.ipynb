# %%
from Bio import Entrez
from Bio import Medline
import pandas as pd
from concurrent.futures import ThreadPoolExecutor, as_completed
from itertools import islice
import multiprocessing
from urllib.error import HTTPError
from collections import Counter
from gensim.parsing.preprocessing import preprocess_string,strip_tags, strip_punctuation, remove_stopwords
import re

# %%
#Functions to retrieve Pubmed Data 
def doc_function(url, count = 0):
    """
    doc_function that retrieves pubmed articles from the queried term
    input: search query
    output: dictionary of:
    abstracts, titles, journals, PMIDS
    """

    # this can be abstracted to a dictionary
    # try block to retrieve the data for the query
    try:
        Entrez.email = "maximilian.zeidler@i-med.ac.at"
        esearch_query = Entrez.esearch(db="pubmed", term=url,retmax = 200000)
        esearch_result = Entrez.read(esearch_query)
        count = esearch_result['Count']
        esearch_query1 = Entrez.esearch(db="pubmed", term=url, retmax = count, retmode = "xlm")
        esearch_result1 = Entrez.read(esearch_query1)
        idlist = esearch_result1["IdList"]
        handle = Entrez.efetch(db="pubmed", id=idlist, rettype="medline", retmode="text", retmax = count)
        records = Medline.parse(handle)
        chunked_records = chunk(records, 20)
        records_dataframe_list = progress_records_multiprocessing(chunked_records)
        final_dataframe = append_dataframes(records_dataframe_list)
        return final_dataframe
    except HTTPError:
        count += 1
        time.sleep(10)
        if count < 5:
            doc_function(url, count)
        else:
            raise ConnectionError
            print("No connection can be established")
            
def retrieve_records(records):
    """
    This function retrieves the abstracts, id and title from the 
    Records.
    The input is a generator which will be evualted lazy per record
    
    """
    print("new Thread")
    corpus_dictionary = {"ID": [], 
                         "abstract": [],
                         "Title":[], 
                         "Journal": [],
                         "Publication_date":[], 
                         "first":[], 
                         "last": []
                        }
    for record in records:
        try:
            if (("DP") in record.keys() and ("PMID") in record.keys() and ("AB") in record.keys() and ("TI") in record.keys() and ("JT") in record.keys() and ("FAU") in record.keys()):
                corpus_dictionary["ID"].append(record["PMID"])
                corpus_dictionary["abstract"].append(record["AB"])
                corpus_dictionary["Title"].append(record["TI"])
                corpus_dictionary["Journal"].append(record["JT"])
                corpus_dictionary["Publication_date"].append(record["DP"])
                corpus_dictionary["first"].append(record["FAU"][0])
                corpus_dictionary["last"].append(record["FAU"][-1])
            else:
                print("Searched record is not available")
                pass
        except:
            pass

    record_dataframe = pd.DataFrame(corpus_dictionary)
    return record_dataframe
    
def progress_records_multiprocessing(records_list, workers = 8):
        """Runs the Worker Thread for each chunk and returns an iterator of the list
        results of the records fetched from the PubMed Outline
        Args:
            new_list (_type_): _description_
        Returns:
            _type_: _description_
        """
        with ThreadPoolExecutor(max_workers=workers) as executor:
            return executor.map(retrieve_records, records_list, timeout=60)

def chunk(it, size):
        """List will be chunked into equally sized parts
        Args:
            it (list): will be the iterable of the list
            size (int): describes the number of chunks based on size per chunk
        Returns:
            iter : iterable object for all chunks (Generator)
        """
        it = iter(it)
        return iter(lambda: tuple(islice(it, size)), ())
    
def append_dataframes(records:list) -> pd.DataFrame:
    """ Goes through the dataframes and appends all the chunked
    dataframes to one final dataframe
    
    """
    final_records = pd.DataFrame()
    for i in records:
        final_records = pd.concat([final_records, i], axis = 0)
    return final_records

# %%
# retrieve the search term
url = "IL-6"
records_dataframes = doc_function(url) # get the abstracts from pubmed
# Out:
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# Searched record is not available
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# Searched record is not available
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# Searched record is not available
# new Thread
# new Thread
# Searched record is not available
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# Searched record is not available
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# Searched record is not available
# Searched record is not available
# new Thread
# new Thread
# new Thread
# new Thread
# Searched record is not available
# new Thread
# new Thread
# Searched record is not available
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# Searched record is not available
# new Thread
# new Thread
# Searched record is not available
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# Searched record is not available
# new Thread
# Searched record is not available
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# Searched record is not available
# Searched record is not available
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# Searched record is not available
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# Searched record is not available
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# Searched record is not available
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# Searched record is not available
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# Searched record is not available
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# Searched record is not available
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# Searched record is not available
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# Searched record is not available
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# Searched record is not available
# new Thread
# Searched record is not available
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# Searched record is not available
# Searched record is not available
# new Thread
# Searched record is not available
# new Thread
# new Thread
# new Thread
# Searched record is not available
# new Thread
# Searched record is not available
# new Thread
# Searched record is not available
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# Searched record is not available
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# Searched record is not available
# Searched record is not available
# new Thread
# new Thread
# Searched record is not available
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# Searched record is not available
# new Thread
# new Thread
# new Thread
# Searched record is not available
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# Searched record is not available
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# Searched record is not available
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# Searched record is not available
# new Thread
# new Thread
# new Thread
# new Thread
# Searched record is not available
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# Searched record is not available
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# Searched record is not available
# Searched record is not available
# new Thread
# Searched record is not available
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# Searched record is not available
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# Searched record is not available
# new Thread
# new Thread
# new Thread
# Searched record is not available
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# Searched record is not available
# Searched record is not available
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# Searched record is not available
# new Thread
# Searched record is not available
# new Thread
# Searched record is not available
# Searched record is not available
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# Searched record is not available
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# Searched record is not available
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# Searched record is not available
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# Searched record is not available
# new Thread
# new Thread
# Searched record is not available
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# Searched record is not available
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# Searched record is not available
# new Thread
# new Thread
# new Thread
# new Thread
# Searched record is not available
# Searched record is not available
# Searched record is not available
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# Searched record is not available
# new Thread
# new Thread
# Searched record is not available
# new Thread
# new Thread
# Searched record is not available
# Searched record is not available
# new Thread
# new Thread
# Searched record is not available
# new Thread
# Searched record is not available
# new Thread
# new Thread
# new Thread
# new Thread
# Searched record is not available
# Searched record is not available
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# new Thread
# Searched record is not available

# %%
# get overview
records_dataframes.head()
# Out:
#          ID                                           abstract  \
# 0  36594412  1-Octacosanol (Octa) is reported to possess ma...
# 1  36594097  Acute kidney injury (AKI) is a pathological co...
# 2  36594093  Rheumatoid arthritis (RA) is a prototypic infl...
# 3  36594066  OBJECTIVES: To investigate the effect of mogro...
# 4  36594061  OBJECTIVES: The current study, the first of it...
#
#                                                Title  \
# 0  Orally administered octacosanol improves liver...
# 1  Direct targeting of sEH with alisol B alleviat...
# 2  Nesfatin-1 Stimulates CCL2-dependent Monocyte ...
# 3  Inhibition of Mogroside IIIE on isoproterenol-...
# 4  Thymoquinone played a protective role against ...
#
#                                         Journal Publication_date  \
# 0                               Food & function       2023 Jan 3
# 1  International journal of biological sciences             2023
# 2  International journal of biological sciences             2023
# 3     Iranian journal of basic medical sciences         2023 Jan
# 4     Iranian journal of basic medical sciences         2023 Jan
#
#                  first                   last
# 0         Ding, Yin-Yi             Shen, Qing
# 1          Zhang, Juan           Ma, Xiao-Chi
# 2       Chang, Jun-Way        Tang, Chih-Hsin
# 3           Yanan, Shi               Wei, Liu
# 4  Demircigil, Nursena  Erdemli, Mehmet Erman

# %%
# this is important to get an overview over missing data and the inferred data types per column
print(records_dataframes.info())
# gets overview over the most frequent data 
# also usually used to retrieve min, max, mean for each column if numeric, int, float
print(records_dataframes.describe())
# exploratory data analysis
# using counter object from the collections package
top_journals = Counter(records_dataframes["Journal"].tolist())
top_journals
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9926 entries, 0 to 17
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                9926 non-null   object
#  1   abstract          9926 non-null   object
#  2   Title             9926 non-null   object
#  3   Journal           9926 non-null   object
#  4   Publication_date  9926 non-null   object
#  5   first             9926 non-null   object
#  6   last              9926 non-null   object
# dtypes: object(7)
# memory usage: 620.4+ KB
# None
#               ID                                           abstract  \
# count       9926                                               9926
# unique      9926                                               9924
# top     36594412  Decades of research have established atheroscl...
# freq           1                                                  2
#
#                                                     Title  \
# count                                                9926
# unique                                               9923
# top     Double-Stranded RNA Induces Mortality in an MD...
# freq                                                    2
#
#                                             Journal Publication_date  \
# count                                          9926             9926
# unique                                         2039              385
# top     International journal of molecular sciences             2022
# freq                                            313             2278
#
#             first     last
# count        9926     9926
# unique       9335     8900
# top     Liu, Ying  Li, Wei
# freq            7        7
# Counter({'Food & function': 66,
#          'International journal of biological sciences': 7,
#          'Iranian journal of basic medical sciences': 24,
#          'Current research in pharmacology and drug discovery': 2,
#          'BioMed research international': 59,
#          'Medical science monitor : international medical journal of experimental and clinical research': 7,
#          'American journal of reproductive immunology (New York, N.Y. : 1989)': 12,
#          'In vivo (Athens, Greece)': 9,
#          'Cellular and molecular gastroenterology and hepatology': 4,
#          'Journal of ethnopharmacology': 101,
#          'Neuroscience letters': 16,
#          'Environmental research': 4,
#          'Brain research': 3,
#          'Journal of animal science': 6,
#          'Transplantation and cellular therapy': 2,
#          'Neurochemistry international': 4,
#          'Journal of biotechnology': 1,
#          'Archives of biochemistry and biophysics': 4,
#          'Microbial pathogenesis': 25,
#          'European journal of cancer (Oxford, England : 1990)': 1,
#          'The Journal of infectious diseases': 6,
#          'Human & experimental toxicology': 15,
#          'QJM : monthly journal of the Association of Physicians': 2,
#          'Current eye research': 3,
#          'European review for medical and pharmacological sciences': 22,
#          'Wiadomosci lekarskie (Warsaw, Poland : 1960)': 5,
#          'Frontiers in oncology': 33,
#          'Frontiers in immunology': 304,
#          'Food & nutrition research': 6,
#          'Journal of the West African College of Surgeons': 1,
#          'JTCVS open': 2,
#          'Cell reports methods': 1,
#          'Frontiers in psychiatry': 23,
#          'Frontiers in microbiology': 53,
#          '3 Biotech': 5,
#          'Frontiers in nutrition': 79,
#          'Oxidative medicine and cellular longevity': 54,
#          'Archives of rheumatology': 4,
#          'Frontiers in physiology': 40,
#          'Experimental and therapeutic medicine': 37,
#          'Qatar medical journal': 1,
#          'Frontiers in pharmacology': 213,
#          'Ulusal travma ve acil cerrahi dergisi = Turkish journal of trauma & emergency surgery : TJTES': 5,
#          'Biomarkers : biochemical indicators of exposure, response, and susceptibility to chemicals': 5,
#          'The Egyptian journal of immunology': 4,
#          'Virus research': 4,
#          'Brain, behavior, and immunity': 25,
#          'Biomedicine & pharmacotherapy = Biomedecine & pharmacotherapie': 73,
#          'International immunopharmacology': 118,
#          'European journal of medicinal chemistry': 9,
#          'BMC pregnancy and childbirth': 1,
#          'Scientific reports': 141,
#          'Trends in immunology': 1,
#          'Journal of microbiology, immunology, and infection = Wei mian yu gan ran za zhi': 3,
#          'Toxicology letters': 6,
#          'Molecular metabolism': 3,
#          'Veterinary parasitology': 3,
#          'Biochemical and biophysical research communications': 26,
#          'Immunobiology': 10,
#          'Clinical and investigative medicine. Medecine clinique et experimentale': 1,
#          'Inflammopharmacology': 30,
#          'Cancer immunology, immunotherapy : CII': 4,
#          'Journal of cellular biochemistry': 4,
#          'Iranian journal of immunology : IJI': 5,
#          'BMC geriatrics': 3,
#          'BMC complementary medicine and therapies': 20,
#          'NPJ biofilms and microbiomes': 2,
#          'International endodontic journal': 10,
#          'Journal of thermal biology': 1,
#          'The Science of the total environment': 12,
#          'The journal of pain': 2,
#          'International journal of biological macromolecules': 43,
#          'Virology': 2,
#          'Phytomedicine : international journal of phytotherapy and phytopharmacology': 47,
#          'Research in veterinary science': 11,
#          'Cytokine': 46,
#          'PloS one': 87,
#          'FASEB journal : official publication of the Federation of American Societies for Experimental Biology': 14,
#          'Folia histochemica et cytobiologica': 3,
#          'Avicenna journal of phytomedicine': 3,
#          'Journal of inflammation research': 32,
#          'Frontiers in cellular and infection microbiology': 53,
#          'Evidence-based complementary and alternative medicine : eCAM': 171,
#          'Journal of immunology research': 26,
#          'Problemy radiatsiinoi medytsyny ta radiobiolohii': 2,
#          'Brain and behavior': 9,
#          'International journal of dermatology': 2,
#          'Cornea': 1,
#          'Journal of neuroinflammation': 28,
#          'Fish & shellfish immunology': 38,
#          'Food and chemical toxicology : an international journal published for the British Industrial Biological Research Association': 11,
#          'The journal of allergy and clinical immunology. In practice': 2,
#          'Antiviral research': 2,
#          'Arquivos de neuro-psiquiatria': 2,
#          'Anesthesia and analgesia': 2,
#          'Journal of molecular neuroscience : MN': 4,
#          'Asian Pacific journal of cancer prevention : APJCP': 4,
#          'Journal of population therapeutics and clinical pharmacology = Journal de la therapeutique des populations et de la pharmacologie clinique': 2,
#          'Surgical infections': 1,
#          'Current opinion in organ transplantation': 2,
#          'Journal of personalized medicine': 20,
#          'Annals of clinical and translational neurology': 1,
#          'Frontiers in endocrinology': 38,
#          'World journal of diabetes': 4,
#          'Heliyon': 31,
#          'Mediators of inflammation': 25,
#          'Current drug targets': 3,
#          'Arthritis research & therapy': 21,
#          'Journal of orthopaedic surgery and research': 9,
#          'Chinese medicine': 7,
#          'Revue des maladies respiratoires': 1,
#          'Schizophrenia research': 1,
#          'Journal of medicinal food': 9,
#          "Naunyn-Schmiedeberg's archives of pharmacology": 9,
#          'Critical reviews in food science and nutrition': 2,
#          'Immunological investigations': 5,
#          'Autophagy': 2,
#          'Expert review of gastroenterology & hepatology': 1,
#          'Journal of cosmetic dermatology': 4,
#          'Frontiers in bioscience (Scholar edition)': 1,
#          'Molecular therapy : the journal of the American Society of Gene Therapy': 4,
#          'Arthritis & rheumatology (Hoboken, N.J.)': 6,
#          'BMC nutrition': 1,
#          'Respiratory research': 14,
#          'Internal medicine (Tokyo, Japan)': 11,
#          'BMJ case reports': 6,
#          'Life sciences': 39,
#          'Clinical biochemistry': 3,
#          'Drug research': 1,
#          'Journal of gastroenterology and hepatology': 4,
#          'Experimental hematology': 1,
#          'Vestnik oftalmologii': 1,
#          'International journal of cardiology. Cardiovascular risk and prevention': 1,
#          'Journal of evolutionary biochemistry and physiology': 2,
#          'Drug design, development and therapy': 24,
#          'Current Alzheimer research': 2,
#          'BMC pulmonary medicine': 8,
#          'Oncogene': 4,
#          'Translational psychiatry': 7,
#          'Journal of cystic fibrosis : official journal of the European Cystic Fibrosis Society': 2,
#          'Resuscitation': 1,
#          'Toxicology and applied pharmacology': 10,
#          'The Journal of nutritional biochemistry': 13,
#          'Skin pharmacology and physiology': 1,
#          'Psychiatry research': 5,
#          'La Tunisie medicale': 2,
#          'Genes & genomics': 1,
#          'Molecular biology reports': 27,
#          'Anesthesiology': 1,
#          'Journal of visualized experiments : JoVE': 2,
#          'Zhen ci yan jiu = Acupuncture research': 16,
#          'Open forum infectious diseases': 4,
#          'Biomedical reports': 3,
#          'Phytomedicine plus : international journal of phytotherapy and phytopharmacology': 2,
#          'Advanced therapeutics': 1,
#          'World journal of gastroenterology': 9,
#          'World journal of clinical cases': 16,
#          'Journal of medicine and life': 5,
#          'Critical care explorations': 4,
#          'Zhonghua wei zhong bing ji jiu yi xue': 16,
#          'Journal of dermatological science': 4,
#          'Journal of cardiothoracic and vascular anesthesia': 2,
#          'Injury': 1,
#          'International journal of infectious diseases : IJID : official publication of the International Society for Infectious Diseases': 9,
#          'European journal of nutrition': 11,
#          'Journal of Ayub Medical College, Abbottabad : JAMC': 2,
#          'European journal of pharmacology': 32,
#          'Respiratory physiology & neurobiology': 3,
#          'Neuroscience and biobehavioral reviews': 3,
#          'Cellular signalling': 1,
#          'Chemosphere': 11,
#          'Bioorganic chemistry': 17,
#          'Poultry science': 20,
#          'Clinical oral investigations': 9,
#          'BMC molecular and cell biology': 5,
#          'Journal for immunotherapy of cancer': 10,
#          'Comparative biochemistry and physiology. Toxicology & pharmacology : CBP': 7,
#          'Ageing research reviews': 6,
#          'Autoimmunity reviews': 4,
#          'Cell host & microbe': 1,
#          'Aging clinical and experimental research': 5,
#          'Molecular and cellular biochemistry': 13,
#          'Pain medicine (Malden, Mass.)': 2,
#          'Stomatologiia': 1,
#          'Clinical and experimental dental research': 1,
#          'Acta pharmaceutica Sinica. B': 4,
#          'Saudi journal of biological sciences': 12,
#          'Viruses': 21,
#          'Vaccines': 20,
#          'Sensors (Basel, Switzerland)': 2,
#          'Polymers': 9,
#          'Plants (Basel, Switzerland)': 19,
#          'Pharmaceutics': 39,
#          'Pharmaceuticals (Basel, Switzerland)': 41,
#          'Pathogens (Basel, Switzerland)': 19,
#          'Nutrients': 114,
#          'Nanomaterials (Basel, Switzerland)': 8,
#          'Molecules (Basel, Switzerland)': 133,
#          'Microorganisms': 21,
#          'Metabolites': 22,
#          'Membranes': 4,
#          'Medicina (Kaunas, Lithuania)': 20,
#          'Life (Basel, Switzerland)': 36,
#          'Journal of clinical medicine': 66,
#          'International journal of molecular sciences': 313,
#          'International journal of environmental research and public health': 36,
#          'Healthcare (Basel, Switzerland)': 3,
#          'Foods (Basel, Switzerland)': 38,
#          'Genes': 10,
#          'Diagnostics (Basel, Switzerland)': 21,
#          'Cells': 78,
#          'Antioxidants (Basel, Switzerland)': 89,
#          'Animals : an open access journal from MDPI': 40,
#          'Biology': 11,
#          'Brain sciences': 10,
#          'Biomedicines': 63,
#          'Cancers': 41,
#          'Antibiotics (Basel, Switzerland)': 13,
#          'Biomolecules': 22,
#          'Biosensors': 4,
#          'Bioengineering (Basel, Switzerland)': 6,
#          'Medicine': 46,
#          'Trials': 11,
#          'Pediatric rheumatology online journal': 2,
#          'The Journal of neuroscience : the official journal of the Society for Neuroscience': 2,
#          'Chinese journal of natural medicines': 4,
#          'Acta medica Okayama': 3,
#          'The European respiratory journal': 7,
#          'Chemico-biological interactions': 12,
#          'Nanomedicine : nanotechnology, biology, and medicine': 2,
#          'International journal of pharmaceutics': 7,
#          'Kidney international': 5,
#          'Neurological research': 3,
#          'Veterinary sciences': 7,
#          'Toxins': 10,
#          'Pathophysiology : the official journal of the International Society for Pathophysiology': 3,
#          'Marine drugs': 18,
#          'ImmunoHorizons': 5,
#          'Current issues in molecular biology': 26,
#          'Dentistry journal': 3,
#          'Chemical biology & drug design': 2,
#          'Clinical laboratory': 9,
#          'European journal of histochemistry : EJH': 3,
#          'Endocrine, metabolic & immune disorders drug targets': 8,
#          'Cardiovascular therapeutics': 2,
#          'Neural plasticity': 2,
#          'Frontiers in aging neuroscience': 11,
#          'Annals of translational medicine': 37,
#          'Health science reports': 1,
#          'Zhongguo dang dai er ke za zhi = Chinese journal of contemporary pediatrics': 5,
#          'Inflammation research : official journal of the European Histamine Research Society ... [et al.]': 25,
#          'Metabolic brain disease': 9,
#          'Nature genetics': 1,
#          'Communications biology': 6,
#          'Respiratory investigation': 3,
#          'Archives of medical research': 1,
#          'Ceska gynekologie': 1,
#          'Journal of the mechanical behavior of biomedical materials': 1,
#          'Molecular immunology': 18,
#          'Cell stress & chaperones': 2,
#          'Connective tissue research': 4,
#          'Journal of biochemical and molecular toxicology': 26,
#          'Physiological reports': 10,
#          'Pharmaceutical biology': 23,
#          'Expert review of medical devices': 1,
#          'Annals of clinical case reports': 1,
#          'Maedica': 2,
#          'Journal of pain research': 8,
#          'Cureus': 27,
#          'Infection and drug resistance': 6,
#          'Italian journal of pediatrics': 3,
#          'Particle and fibre toxicology': 2,
#          'BMC anesthesiology': 9,
#          'Journal of perinatology : official journal of the California Perinatal Association': 1,
#          'Georgian medical news': 3,
#          'Acta haematologica': 1,
#          'Journal of immunotoxicology': 3,
#          'ACS chemical neuroscience': 9,
#          'Environmental science and pollution research international': 22,
#          'Biological trace element research': 19,
#          'Genetics and molecular biology': 2,
#          'BJS open': 2,
#          'American journal of physiology. Gastrointestinal and liver physiology': 3,
#          'Indian journal of pharmacology': 2,
#          'International journal of rheumatic diseases': 8,
#          'International journal of toxicology': 2,
#          'International journal of ophthalmology': 5,
#          'BMC ophthalmology': 1,
#          'BMC cancer': 9,
#          'Molecular medicine (Cambridge, Mass.)': 5,
#          'Neurotoxicity research': 9,
#          'Histochemistry and cell biology': 3,
#          'Acta pharmacologica Sinica': 2,
#          'Journal of clinical densitometry : the official journal of the International Society for Clinical Densitometry': 1,
#          'Pathogens and disease': 2,
#          'Complementary therapies in medicine': 5,
#          'Diabetes & metabolic syndrome': 2,
#          'EBioMedicine': 9,
#          'Dermatology practical & conceptual': 1,
#          'Blood advances': 5,
#          'Clinical and experimental rheumatology': 7,
#          'Shock (Augusta, Ga.)': 12,
#          'Clinical Medicine Insights. Oncology': 1,
#          'Iranian journal of microbiology': 1,
#          'Frontiers in cardiovascular medicine': 42,
#          'Oncoimmunology': 2,
#          'Ophthalmology science': 1,
#          'Journal of Indian Association of Pediatric Surgeons': 1,
#          'Frontiers in public health': 11,
#          'Frontiers in neurology': 15,
#          'Radiology case reports': 2,
#          'ACS omega': 15,
#          'Journal of agricultural and food chemistry': 30,
#          'European journal of medical research': 6,
#          'Chemistry & biodiversity': 11,
#          'Psychoneuroendocrinology': 13,
#          'Tissue & cell': 9,
#          'Pediatric neurology': 1,
#          'Journal of reproductive immunology': 9,
#          'International journal of obesity (2005)': 3,
#          'Journal of endodontics': 2,
#          'Biomaterials advances': 10,
#          'Food chemistry': 9,
#          'Journal of plastic, reconstructive & aesthetic surgery : JPRAS': 1,
#          'Journal of autoimmunity': 2,
#          'Current microbiology': 4,
#          'Clinical oncology (Royal College of Radiologists (Great Britain))': 1,
#          'Mechanisms of ageing and development': 3,
#          'Experimental gerontology': 8,
#          'Neurobiology of disease': 5,
#          'Archives of gerontology and geriatrics': 3,
#          'AIDS (London, England)': 9,
#          'The International journal of neuroscience': 5,
#          'Journal of clinical laboratory analysis': 21,
#          'JAMA': 2,
#          'Journal of natural medicines': 2,
#          'Journal of cellular and molecular medicine': 8,
#          'Molecular medicine reports': 18,
#          'Journal of thoracic disease': 11,
#          'Advances in virology': 2,
#          'Translational cancer research': 3,
#          'BMJ open': 9,
#          'Clinical and applied thrombosis/hemostasis : official journal of the International Academy of Clinical and Applied Thrombosis/Hemostasis': 2,
#          'Journal of cerebral blood flow and metabolism : official journal of the International Society of Cerebral Blood Flow and Metabolism': 3,
#          'Probiotics and antimicrobial proteins': 12,
#          'Journal of clinical lipidology': 1,
#          'The Journal of rheumatology': 1,
#          'Asian journal of psychiatry': 1,
#          'Kardiologiia': 3,
#          'ACS applied materials & interfaces': 9,
#          'JCI insight': 6,
#          'Journal of global health': 1,
#          'Cardiovascular toxicology': 2,
#          'Journal of neurochemistry': 1,
#          'Critical care medicine': 3,
#          'Toxicological sciences : an official journal of the Society of Toxicology': 4,
#          'Bratislavske lekarske listy': 4,
#          'The Journal of clinical investigation': 5,
#          'Translational lung cancer research': 4,
#          'Frontiers in pediatrics': 12,
#          'ACS medicinal chemistry letters': 1,
#          'Toxicology reports': 5,
#          'Bioinformation': 2,
#          'Tissue engineering. Part A': 1,
#          'Pharmacological reports : PR': 3,
#          'Supportive care in cancer : official journal of the Multinational Association of Supportive Care in Cancer': 2,
#          'Nefrologia': 3,
#          'Journal of obstetrics and gynaecology : the journal of the Institute of Obstetrics and Gynaecology': 9,
#          'Translational oncology': 4,
#          'Psychosomatic medicine': 4,
#          'Journal of acquired immune deficiency syndromes (1999)': 4,
#          'Drug delivery and translational research': 2,
#          'Zeitschrift fur Rheumatologie': 2,
#          'Acta cirurgica brasileira': 11,
#          'Current diabetes reviews': 1,
#          'Cell proliferation': 5,
#          'Obstetric medicine': 1,
#          'Journal of orthopaedic translation': 7,
#          'Food science & nutrition': 7,
#          'Acta biochimica et biophysica Sinica': 3,
#          'Journal of animal science and biotechnology': 3,
#          'Immunity & ageing : I & A': 7,
#          'Journal of translational medicine': 15,
#          'Gastric cancer : official journal of the International Gastric Cancer Association and the Japanese Gastric Cancer Association': 1,
#          'Journal of artificial organs : the official journal of the Japanese Society for Artificial Organs': 1,
#          'Planta medica': 7,
#          'Prostaglandins & other lipid mediators': 3,
#          'Toxicology': 8,
#          'Cancer cell': 3,
#          'Ecotoxicology and environmental safety': 42,
#          'International journal of radiation biology': 2,
#          'Neurochemical research': 17,
#          'Infection': 3,
#          'Immunologic research': 8,
#          'Cell biology international': 6,
#          'Drug and chemical toxicology': 4,
#          'Immunology and cell biology': 4,
#          'Parasites & vectors': 2,
#          'Critical care (London, England)': 4,
#          "BMC women's health": 4,
#          'International urology and nephrology': 5,
#          'The American journal of geriatric psychiatry : official journal of the American Association for Geriatric Psychiatry': 1,
#          'International journal of food microbiology': 1,
#          'Journal of neuroimmunology': 12,
#          'The journals of gerontology. Series A, Biological sciences and medical sciences': 3,
#          'Clinical chemistry': 1,
#          'Drugs': 2,
#          'Clinical medicine (London, England)': 1,
#          'Frontiers in medicine': 53,
#          'Frontiers in neuroscience': 17,
#          'Journal of dentistry (Shiraz, Iran)': 1,
#          'Frontiers in aging': 5,
#          'Frontiers in cell and developmental biology': 17,
#          'Veterinary medicine international': 1,
#          'American journal of translational research': 49,
#          'Frontiers in molecular biosciences': 12,
#          'Journal of periodontal research': 8,
#          'Giornale italiano di cardiologia (2006)': 1,
#          'Nan fang yi ke da xue xue bao = Journal of Southern Medical University': 9,
#          'Journal of environmental sciences (China)': 2,
#          'The American journal of Chinese medicine': 6,
#          'BMC infectious diseases': 8,
#          'Human vaccines & immunotherapeutics': 2,
#          'Biosensors & bioelectronics': 5,
#          'Journal of cellular physiology': 6,
#          'Fish physiology and biochemistry': 1,
#          'Virology journal': 4,
#          'Seminars in nuclear medicine': 1,
#          'Cellular and molecular biology (Noisy-le-Grand, France)': 31,
#          'Journal of endocrinological investigation': 5,
#          'Applied biochemistry and biotechnology': 9,
#          'Archives of dermatological research': 3,
#          'Journal of cancer research and clinical oncology': 6,
#          'Nutrition and cancer': 4,
#          'Clinical transplantation': 5,
#          'Molecular oral microbiology': 3,
#          'Journal of the science of food and agriculture': 8,
#          'BMC neurology': 5,
#          'Obesity research & clinical practice': 2,
#          'Journal of dairy science': 13,
#          'Biochimica et biophysica acta. Molecular and cell biology of lipids': 2,
#          'Toxicon : official journal of the International Society on Toxinology': 3,
#          'Experimental neurology': 2,
#          'Aging': 9,
#          'ACS biomaterials science & engineering': 1,
#          'Hematology. American Society of Hematology. Education Program': 1,
#          'Apoptosis : an international journal on programmed cell death': 3,
#          'Phytotherapy research : PTR': 17,
#          'International journal of molecular medicine': 3,
#          'Japanese journal of clinical oncology': 1,
#          'Lab on a chip': 2,
#          'Zhongguo zhen jiu = Chinese acupuncture & moxibustion': 5,
#          'Vascular health and risk management': 1,
#          'medRxiv : the preprint server for health sciences': 5,
#          'Breast cancer (Dove Medical Press)': 1,
#          'Turkish neurosurgery': 4,
#          'Emerging microbes & infections': 5,
#          'BMC rheumatology': 1,
#          'BMC neuroscience': 2,
#          'British journal of cancer': 2,
#          'Cerebellum (London, England)': 1,
#          'In vitro cellular & developmental biology. Animal': 2,
#          'Environmental pollution (Barking, Essex : 1987)': 5,
#          'Cytotherapy': 4,
#          'Cirugia y cirujanos': 2,
#          'Alternative therapies in health and medicine': 5,
#          'Environmental science & technology': 3,
#          'Microbiology and immunology': 5,
#          'FEBS open bio': 1,
#          'Current heart failure reports': 1,
#          'Mikrochimica acta': 2,
#          'Frontiers in molecular neuroscience': 8,
#          'CNS neuroscience & therapeutics': 9,
#          'Pacing and clinical electrophysiology : PACE': 1,
#          'Lower urinary tract symptoms': 1,
#          'Brazilian dental journal': 1,
#          'Clinical pharmacology and therapeutics': 1,
#          'Zhongguo shi yan xue ye xue za zhi': 11,
#          'Behavioral sleep medicine': 1,
#          'Osteoarthritis and cartilage open': 5,
#          'ERJ open research': 3,
#          'Clinical interventions in aging': 3,
#          'Journal of the College of Physicians and Surgeons--Pakistan : JCPSP': 6,
#          "American journal of Alzheimer's disease and other dementias": 2,
#          'Reviews in endocrine & metabolic disorders': 3,
#          'Fitoterapia': 7,
#          'Endocrine connections': 2,
#          'The international journal of neuropsychopharmacology': 2,
#          'Dermatology and therapy': 2,
#          'Wiener medizinische Wochenschrift (1946)': 1,
#          'Archivos espanoles de urologia': 1,
#          'Zhongguo Zhong yao za zhi = Zhongguo zhongyao zazhi = China journal of Chinese materia medica': 43,
#          'BioFactors (Oxford, England)': 4,
#          'Seminars in ophthalmology': 1,
#          'Experimental dermatology': 4,
#          'European journal of applied physiology': 5,
#          'The Journal of heart and lung transplantation : the official publication of the International Society for Heart Transplantation': 1,
#          'International archives of allergy and immunology': 5,
#          'Developmental neuroscience': 1,
#          'Hematology (Amsterdam, Netherlands)': 4,
#          'Natural product research': 7,
#          'JAMA network open': 4,
#          'Internal and emergency medicine': 1,
#          'Terapevticheskii arkhiv': 7,
#          'Journal of analytical methods in chemistry': 1,
#          'Nutrition research and practice': 5,
#          'Brain, behavior, & immunity - health': 22,
#          'Comparative clinical pathology': 2,
#          'Saudi pharmaceutical journal : SPJ : the official publication of the Saudi Pharmaceutical Society': 6,
#          'Journal of oncology pharmacy practice : official publication of the International Society of Oncology Pharmacy Practitioners': 2,
#          'Analytica chimica acta': 1,
#          'Experimental animals': 4,
#          'American journal of obstetrics & gynecology MFM': 1,
#          'Journal of chemical neuroanatomy': 8,
#          'Tuberculosis (Edinburgh, Scotland)': 3,
#          'Animal reproduction science': 1,
#          'Clinical hemorheology and microcirculation': 2,
#          'BMC research notes': 1,
#          'BMC oral health': 4,
#          'Heart, lung & circulation': 2,
#          'The Journal of allergy and clinical immunology': 7,
#          'Bioorganic & medicinal chemistry letters': 3,
#          'Transplant immunology': 7,
#          'Oral oncology': 1,
#          'Environmental toxicology': 13,
#          'Clinical gerontologist': 1,
#          'Food research international (Ottawa, Ont.)': 15,
#          'Laboratory animal research': 3,
#          'Biomarker research': 1,
#          'Medical oncology (Northwood, London, England)': 4,
#          'Immunology letters': 5,
#          'Nutrition (Burbank, Los Angeles County, Calif.)': 4,
#          'Redox biology': 5,
#          'Proceedings of the National Academy of Sciences of the United States of America': 7,
#          'Acta biochimica Polonica': 8,
#          'Inflammation': 31,
#          'Inflammatory bowel diseases': 2,
#          'Allergy': 3,
#          'Journal of cell science': 1,
#          'Anaesthesiology intensive therapy': 1,
#          'Oman medical journal': 1,
#          'Indian journal of psychiatry': 1,
#          'Basic and clinical neuroscience': 2,
#          'Journal of microbiology and biotechnology': 4,
#          'Inflammation and regeneration': 2,
#          'Cell death & disease': 10,
#          'Anticancer research': 6,
#          'Matrix biology : journal of the International Society for Matrix Biology': 1,
#          'Biological psychology': 1,
#          'International journal of cancer': 3,
#          'Journal of psychiatric research': 3,
#          'Clinical and experimental medicine': 4,
#          'GeroScience': 4,
#          'Cannabis and cannabinoid research': 3,
#          'General physiology and biophysics': 3,
#          'The Journal of pathology': 3,
#          'International journal of cosmetic science': 2,
#          'American journal of transplantation : official journal of the American Society of Transplantation and the American Society of Transplant Surgeons': 6,
#          'Avian pathology : journal of the W.V.P.A': 1,
#          'Journal of hypertension': 1,
#          'The Journal of comparative neurology': 1,
#          'Indian journal of ophthalmology': 1,
#          'Arteriosclerosis, thrombosis, and vascular biology': 2,
#          'Clinical ophthalmology (Auckland, N.Z.)': 2,
#          'Journal of inflammation (London, England)': 8,
#          'Cancer chemotherapy and pharmacology': 2,
#          'Nature': 2,
#          'Signal transduction and targeted therapy': 2,
#          'Biological & pharmaceutical bulletin': 9,
#          'Anais da Academia Brasileira de Ciencias': 3,
#          'Revista da Associacao Medica Brasileira (1992)': 6,
#          'Advances in clinical and experimental medicine : official organ Wroclaw Medical University': 10,
#          'JAMA cardiology': 1,
#          'Diabetes': 2,
#          'Infection and immunity': 3,
#          'Glia': 6,
#          'Drug delivery': 10,
#          'Prostate cancer and prostatic diseases': 1,
#          'Nature communications': 18,
#          'Hormone and metabolic research = Hormon- und Stoffwechselforschung = Hormones et metabolisme': 1,
#          'International ophthalmology': 4,
#          'Microbiology spectrum': 17,
#          'Artificial organs': 3,
#          'Pediatric pulmonology': 3,
#          'Immunity, inflammation and disease': 18,
#          'Journal of environmental and public health': 1,
#          'JACC. CardioOncology': 1,
#          'Psychiatry investigation': 1,
#          'Biomolecules & therapeutics': 2,
#          'Radiation oncology (London, England)': 1,
#          'Molecular cancer': 1,
#          'Biologia futura': 1,
#          'Rheumatology and therapy': 2,
#          'Sichuan da xue xue bao. Yi xue ban = Journal of Sichuan University. Medical science edition': 5,
#          'Biomaterials': 3,
#          'Animal : an international journal of animal bioscience': 4,
#          'Blood': 4,
#          'Molecular neurobiology': 15,
#          'Immunology': 5,
#          'Zhurnal nevrologii i psikhiatrii imeni S.S. Korsakova': 4,
#          'Cancer medicine': 9,
#          'Current research in immunology': 2,
#          'Current research in food science': 4,
#          'Biochemistry and biophysics reports': 4,
#          'PeerJ': 13,
#          'Indoor air': 1,
#          'Journal of tissue engineering and regenerative medicine': 3,
#          'Multiple sclerosis (Houndmills, Basingstoke, England)': 1,
#          'Maternal & child nutrition': 1,
#          'Toxicology mechanisms and methods': 3,
#          'Bulletin of experimental biology and medicine': 3,
#          'Animal science journal = Nihon chikusan Gakkaiho': 1,
#          'Current research in translational medicine': 1,
#          'Psychiatry and clinical neurosciences': 2,
#          'Veterinary research': 6,
#          'Journal of shoulder and elbow surgery': 1,
#          'Journal of affective disorders': 10,
#          'Current opinion in immunology': 1,
#          'Journal of neuroscience research': 1,
#          'Human molecular genetics': 1,
#          'BMC endocrine disorders': 5,
#          'Archives of microbiology': 3,
#          'Basic & clinical pharmacology & toxicology': 3,
#          'European journal of immunology': 3,
#          'Diabetes research and clinical practice': 2,
#          'Behavioural brain research': 9,
#          'Developmental and comparative immunology': 12,
#          'Journal of immunology (Baltimore, Md. : 1950)': 15,
#          'International wound journal': 6,
#          'Experimental biology and medicine (Maywood, N.J.)': 6,
#          'American journal of rhinology & allergy': 2,
#          'Frontiers in bioengineering and biotechnology': 17,
#          'RSC advances': 10,
#          'Current pharmaceutical design': 10,
#          'Child and adolescent psychiatry and mental health': 1,
#          'Biochimica et biophysica acta. Molecular basis of disease': 7,
#          'Theriogenology': 5,
#          'Journal of infection and public health': 2,
#          'Acta diabetologica': 1,
#          'Biomaterials science': 3,
#          'Journal of the European Academy of Dermatology and Venereology : JEADV': 3,
#          'Oncology letters': 4,
#          'The Journal of dermatology': 3,
#          'Journal of biomedical science': 3,
#          'Molecular nutrition & food research': 6,
#          'Clinical rheumatology': 10,
#          'Zhonghua xin xue guan bing za zhi': 1,
#          'Zhonghua shao shang za zhi = Zhonghua shaoshang zazhi = Chinese journal of burns': 5,
#          'The Journal of veterinary medical science': 1,
#          'Journal of applied oral science : revista FOB': 2,
#          'Science advances': 6,
#          'British journal of clinical pharmacology': 6,
#          'Human cell': 3,
#          'Journal of periodontology': 5,
#          'Molecular omics': 3,
#          'Journal of the American Heart Association': 4,
#          'Food science of animal resources': 2,
#          'Pakistan journal of medical sciences': 13,
#          'CEN case reports': 1,
#          'Zhongguo ying yong sheng li xue za zhi = Zhongguo yingyong shenglixue zazhi = Chinese journal of applied physiology': 6,
#          'Expert review of clinical immunology': 1,
#          'Rheumatology (Oxford, England)': 10,
#          'Human reproduction (Oxford, England)': 2,
#          'Journal of functional morphology and kinesiology': 1,
#          'Zhong nan da xue xue bao. Yi xue ban = Journal of Central South University. Medical sciences': 7,
#          'Cell communication and signaling : CCS': 3,
#          'Canadian journal of diabetes': 3,
#          'Neurology(R) neuroimmunology & neuroinflammation': 2,
#          'Frontiers in neuroendocrinology': 1,
#          'Journal of controlled release : official journal of the Controlled Release Society': 8,
#          'European journal of obstetrics, gynecology, and reproductive biology': 1,
#          'Archives of oral biology': 5,
#          'American journal of physiology. Lung cellular and molecular physiology': 5,
#          'American journal of respiratory and critical care medicine': 3,
#          'Cancer epidemiology, biomarkers & prevention : a publication of the American Association for Cancer Research, cosponsored by the American Society of Preventive Oncology': 4,
#          'Current topics in behavioral neurosciences': 2,
#          'ACS pharmacology & translational science': 4,
#          'Building and environment': 1,
#          'Clinical and translational radiation oncology': 1,
#          'African health sciences': 2,
#          'Moscow University biological sciences bulletin': 1,
#          'Burns & trauma': 2,
#          'International journal of nanomedicine': 6,
#          'Journal of clinical and translational hepatology': 3,
#          'Bioactive materials': 4,
#          'Frontiers in veterinary science': 47,
#          'Nano research': 2,
#          'Open life sciences': 4,
#          'Chinese herbal medicines': 2,
#          'Therapeutic advances in respiratory disease': 2,
#          'Pharmacology research & perspectives': 2,
#          'Archives of Iranian medicine': 1,
#          'BMC gastroenterology': 2,
#          'World neurosurgery': 4,
#          'The Journal of surgical research': 7,
#          'Lasers in surgery and medicine': 1,
#          'Journal of burn care & research : official publication of the American Burn Association': 2,
#          'Vnitrni lekarstvi': 2,
#          'Neurotoxicology': 5,
#          'Advances in gerontology = Uspekhi gerontologii': 1,
#          'Oral diseases': 5,
#          'Chinese journal of integrative medicine': 4,
#          'ESC heart failure': 4,
#          'Human immunology': 1,
#          'Translational research : the journal of laboratory and clinical medicine': 1,
#          'Experimental eye research': 5,
#          'Journal of medicinal chemistry': 3,
#          'Molecular pharmaceutics': 5,
#          'Analytical chemistry': 5,
#          'Klinicheskaia laboratornaia diagnostika': 3,
#          'Veterinaria italiana': 1,
#          'Canadian journal of gastroenterology & hepatology': 2,
#          'International journal of inflammation': 3,
#          'Animal bioscience': 3,
#          'Current neurovascular research': 2,
#          'Equine veterinary journal': 1,
#          'Diabetology & metabolic syndrome': 4,
#          'HRB open research': 1,
#          'Pancreas': 2,
#          'Nucleosides, nucleotides & nucleic acids': 2,
#          'Photobiomodulation, photomedicine, and laser surgery': 3,
#          'British journal of pharmacology': 6,
#          'Physiotherapy theory and practice': 1,
#          'Journal of gastrointestinal oncology': 6,
#          'International journal of sexual health : official journal of the World Association for Sexual Health': 1,
#          'Frontiers in genetics': 11,
#          'Research in pharmaceutical sciences': 1,
#          'Cell reports. Medicine': 3,
#          'Clinical neuropharmacology': 2,
#          'American journal of physiology. Endocrinology and metabolism': 2,
#          'European journal of clinical microbiology & infectious diseases : official publication of the European Society of Clinical Microbiology': 1,
#          'Digestive diseases and sciences': 4,
#          'Journal of long-term effects of medical implants': 1,
#          'Folia neuropathologica': 1,
#          'Epidemiology and infection': 1,
#          'Transplantation direct': 3,
#          'Clinical nutrition research': 2,
#          'Reumatologia': 2,
#          'Journal of medical biochemistry': 4,
#          'PNAS nexus': 2,
#          'Research square': 2,
#          'Mycoses': 2,
#          'The FEBS journal': 3,
#          'Tropical animal health and production': 3,
#          'Journal of neuroimmune pharmacology : the official journal of the Society on NeuroImmune Pharmacology': 1,
#          'Journal of Zhejiang University. Science. B': 2,
#          'European journal of pediatric surgery : official journal of Austrian Association of Pediatric Surgery ... [et al] = Zeitschrift fur Kinderchirurgie': 2,
#          'Biochimica et biophysica acta. General subjects': 2,
#          'Acta cardiologica': 2,
#          'Cellular physiology and biochemistry : international journal of experimental cellular physiology, biochemistry, and pharmacology': 3,
#          'Journal of traditional Chinese medicine = Chung i tsa chih ying wen pan': 7,
#          'ACS infectious diseases': 3,
#          'Beneficial microbes': 1,
#          'Journal of cachexia, sarcopenia and muscle': 7,
#          'Cell journal': 2,
#          'Animal models and experimental medicine': 3,
#          'Domestic animal endocrinology': 2,
#          'Pain physician': 2,
#          'International journal of medicinal mushrooms': 2,
#          'Clinical cancer research : an official journal of the American Association for Cancer Research': 1,
#          'JMIR research protocols': 3,
#          'Andrologia': 4,
#          'Journal of chromatography. B, Analytical technologies in the biomedical and life sciences': 1,
#          'European journal of surgical oncology : the journal of the European Society of Surgical Oncology and the British Association of Surgical Oncology': 2,
#          'Transplantation proceedings': 4,
#          'BMC pediatrics': 2,
#          'Peptides': 5,
#          'The Journal of biological chemistry': 5,
#          'Journal of electrocardiology': 1,
#          'Journal of the Pediatric Infectious Diseases Society': 1,
#          'NPJ breast cancer': 2,
#          'Breast cancer research and treatment': 1,
#          'Neurological sciences : official journal of the Italian Neurological Society and of the Italian Society of Clinical Neurophysiology': 2,
#          'Journal of nanobiotechnology': 7,
#          'BMC psychiatry': 3,
#          'Annals of the rheumatic diseases': 10,
#          'Acta tropica': 4,
#          'Clinics (Sao Paulo, Brazil)': 1,
#          'Neuropeptides': 2,
#          'Neuroreport': 4,
#          'The Journal of experimental medicine': 1,
#          'American journal of physiology. Heart and circulatory physiology': 3,
#          'Children (Basel, Switzerland)': 9,
#          'Diabetes & vascular disease research': 1,
#          'Journal of clinical periodontology': 5,
#          'Free radical biology & medicine': 8,
#          'The Lancet. Infectious diseases': 1,
#          'Epilepsy & behavior : E&B': 1,
#          'Endocrine-related cancer': 2,
#          'Toxics': 5,
#          'Tropical medicine and infectious disease': 1,
#          'Chinese medical journal': 2,
#          'Sports (Basel, Switzerland)': 3,
#          'Carcinogenesis': 2,
#          'Global spine journal': 1,
#          'Viral immunology': 3,
#          'Liver international : official journal of the International Association for the Study of the Liver': 2,
#          'Journal of research in medical sciences : the official journal of Isfahan University of Medical Sciences': 2,
#          'Journal of family medicine and primary care': 3,
#          'Discover. Oncology': 1,
#          'Advanced healthcare materials': 2,
#          'Journal of sport and health science': 1,
#          'Journal of food biochemistry': 28,
#          'Arquivos brasileiros de oftalmologia': 2,
#          'Acta veterinaria Hungarica': 1,
#          'Current medical science': 4,
#          'Journal of cancer survivorship : research and practice': 1,
#          'World journal of microbiology & biotechnology': 1,
#          'Plant foods for human nutrition (Dordrecht, Netherlands)': 3,
#          'Journal of investigative surgery : the official journal of the Academy of Surgical Research': 5,
#          'The American journal of sports medicine': 3,
#          'International journal of nephrology and renovascular disease': 1,
#          'Romanian journal of ophthalmology': 1,
#          'eNeurologicalSci': 1,
#          'Phytochemistry': 8,
#          'Seminars in arthritis and rheumatism': 2,
#          'Science signaling': 3,
#          'The Journal of clinical endocrinology and metabolism': 5,
#          'Innere Medizin (Heidelberg, Germany)': 1,
#          'Journal of interferon & cytokine research : the official journal of the International Society for Interferon and Cytokine Research': 8,
#          'mSystems': 3,
#          'Pediatric endocrinology, diabetes, and metabolism': 1,
#          'Therapeutic apheresis and dialysis : official peer-reviewed journal of the International Society for Apheresis, the Japanese Society for Apheresis, the Japanese Society for Dialysis Therapy': 3,
#          'Translational pediatrics': 5,
#          'Animal diseases': 1,
#          'Orphanet journal of rare diseases': 2,
#          'Archiv der Pharmazie': 1,
#          'Annals of allergy, asthma & immunology : official publication of the American College of Allergy, Asthma, & Immunology': 1,
#          'International journal of sports physiology and performance': 1,
#          'Comparative immunology, microbiology and infectious diseases': 1,
#          'Applied microbiology and biotechnology': 3,
#          'Journal of food science': 4,
#          'Redox report : communications in free radical research': 4,
#          'IET nanobiotechnology': 1,
#          'EMBO reports': 3,
#          'Journal of human reproductive sciences': 1,
#          'Journal of bone oncology': 1,
#          'Exploration of targeted anti-tumor therapy': 1,
#          'Nature cardiovascular research': 1,
#          'Immunometabolism (Cobham (Surrey, England))': 1,
#          'The journal of cardiovascular aging': 1,
#          'Toxicology research': 4,
#          'Neurotrauma reports': 2,
#          'Bosnian journal of basic medical sciences': 6,
#          'Life sciences in space research': 1,
#          'Journal of oleo science': 8,
#          'Computers in biology and medicine': 2,
#          'Allergologia et immunopathologia': 22,
#          'Experimental cell research': 8,
#          'Molecular and cellular endocrinology': 2,
#          'Obesity surgery': 1,
#          'Journal of neural transmission (Vienna, Austria : 1996)': 1,
#          'Biological research': 1,
#          'Journal of hematology & oncology': 1,
#          'Amino acids': 1,
#          'Brain research bulletin': 5,
#          'Stem cell reports': 3,
#          'Ocular immunology and inflammation': 2,
#          'The Journal of asthma : official journal of the Association for the Care of Asthma': 3,
#          'Forensic science, medicine, and pathology': 1,
#          'Bioscience, biotechnology, and biochemistry': 2,
#          'Pharmaceutical development and technology': 1,
#          'TheScientificWorldJournal': 1,
#          'Journal of clinical immunology': 4,
#          'Nephrologie & therapeutique': 1,
#          'Neuropathology : official journal of the Japanese Society of Neuropathology': 1,
#          'Journal of advanced research': 3,
#          'Infectious disease clinics of North America': 2,
#          'ACS applied bio materials': 2,
#          'Turkish journal of medical sciences': 5,
#          'Immunopharmacology and immunotoxicology': 20,
#          'Zhongguo yi xue ke xue yuan xue bao. Acta Academiae Medicinae Sinicae': 6,
#          'Journal of traditional and complementary medicine': 7,
#          'Clinical, cosmetic and investigational dermatology': 6,
#          'iScience': 7,
#          'Therapeutic advances in chronic disease': 2,
#          'Cerebral circulation - cognition and behavior': 1,
#          'Journal of medical case reports': 1,
#          'NPJ microgravity': 2,
#          'International journal of immunogenetics': 1,
#          'Andrology': 3,
#          'Blood purification': 4,
#          'The Journal of antimicrobial chemotherapy': 3,
#          'BioDrugs : clinical immunotherapeutics, biopharmaceuticals and gene therapy': 1,
#          'Combinatorial chemistry & high throughput screening': 5,
#          'International journal of cardiology. Heart & vasculature': 1,
#          'Molecular diversity': 1,
#          'Zhonghua er bi yan hou tou jing wai ke za zhi = Chinese journal of otorhinolaryngology head and neck surgery': 3,
#          'Sheng li xue bao : [Acta physiologica Sinica]': 5,
#          'ASAIO journal (American Society for Artificial Internal Organs : 1992)': 1,
#          'ACS nano': 3,
#          'Mycopathologia': 1,
#          'Virchows Archiv : an international journal of pathology': 1,
#          'Gut and liver': 1,
#          'Nutrition & metabolism': 3,
#          'Neurology': 5,
#          'American journal of hypertension': 1,
#          'Biomolecular concepts': 1,
#          'International journal of immunopathology and pharmacology': 6,
#          'Pain': 2,
#          'Journal of pharmaceutical analysis': 1,
#          'EJIFCC': 1,
#          'Journal of tropical medicine': 2,
#          'Veterinary world': 5,
#          'Food science and biotechnology': 6,
#          'Journal of ginseng research': 5,
#          'Journal of oral microbiology': 2,
#          'OncoTargets and therapy': 1,
#          'Journal of toxicology': 1,
#          'Bioelectromagnetics': 1,
#          'Journal of nutritional science and vitaminology': 3,
#          'Annals of vascular surgery': 1,
#          'International forum of allergy & rhinology': 2,
#          'Indian journal of pathology & microbiology': 1,
#          'Cells & development': 1,
#          'Differentiation; research in biological diversity': 1,
#          'Journal de mycologie medicale': 2,
#          'Cell and tissue research': 2,
#          'Diabetes, obesity & metabolism': 1,
#          'Anti-inflammatory & anti-allergy agents in medicinal chemistry': 1,
#          'Proceedings (Baylor University. Medical Center)': 2,
#          'Frontiers in reproductive health': 1,
#          'BMC microbiology': 3,
#          'Nature neuroscience': 1,
#          'Journal of physiology and pharmacology : an official journal of the Polish Physiological Society': 2,
#          'Molecular and cellular neurosciences': 4,
#          'Neuropsychobiology': 1,
#          'The Journal of pharmacy and pharmacology': 5,
#          'Experimental brain research': 3,
#          'Addiction biology': 2,
#          'Transfusion': 1,
#          'International journal of dental hygiene': 1,
#          'Anatomical record (Hoboken, N.J. : 2007)': 1,
#          'Bioscience reports': 3,
#          'Frontiers in chemistry': 5,
#          'Frontiers in surgery': 15,
#          'Stem cells international': 10,
#          'Brain : a journal of neurology': 4,
#          'Renal failure': 5,
#          'Journal of fungi (Basel, Switzerland)': 5,
#          'Current oncology (Toronto, Ont.)': 2,
#          'The Tohoku journal of experimental medicine': 5,
#          'Cancer genetics': 1,
#          'Hormone molecular biology and clinical investigation': 3,
#          'Journal of animal science and technology': 2,
#          'Revista da Sociedade Brasileira de Medicina Tropical': 1,
#          'European heart journal': 3,
#          'Canadian journal of physiology and pharmacology': 2,
#          'Advances in respiratory medicine': 2,
#          'Minerva endocrinology': 1,
#          'Journal of healthcare engineering': 4,
#          'Current molecular medicine': 3,
#          'Current pharmaceutical biotechnology': 1,
#          'ChemistryOpen': 1,
#          'Cellular and molecular life sciences : CMLS': 8,
#          'Progress in neuro-psychopharmacology & biological psychiatry': 5,
#          'Clinica chimica acta; international journal of clinical chemistry': 2,
#          'Nutrition research (New York, N.Y.)': 5,
#          'American journal of physiology. Regulatory, integrative and comparative physiology': 3,
#          'Developmental psychobiology': 1,
#          'PLoS pathogens': 7,
#          'Recent advances in drug delivery and formulation': 1,
#          'Xenobiotica; the fate of foreign compounds in biological systems': 1,
#          'SAGE open medicine': 2,
#          'Computational and mathematical methods in medicine': 47,
#          'Biomarker insights': 4,
#          "Journal of Alzheimer's disease reports": 1,
#          'Journal of Nippon Medical School = Nippon Ika Daigaku zasshi': 1,
#          'Cell & bioscience': 4,
#          'Vaccine': 2,
#          'Pharmacological research': 7,
#          'Pharmacology, biochemistry, and behavior': 3,
#          'Journal of biomolecular structure & dynamics': 2,
#          'Virulence': 2,
#          'Expert opinion on pharmacotherapy': 2,
#          'Journal of clinical pharmacy and therapeutics': 2,
#          'RMD open': 2,
#          'International journal of sport nutrition and exercise metabolism': 1,
#          'Clinical neurology and neurosurgery': 4,
#          'PLoS neglected tropical diseases': 10,
#          'International journal of clinical oncology': 1,
#          'Assay and drug development technologies': 1,
#          'Annals of medicine and surgery (2012)': 6,
#          'Movement disorders : official journal of the Movement Disorder Society': 2,
#          'European cytokine network': 1,
#          'Revista internacional de andrologia': 1,
#          'Neuroscience': 7,
#          'Zeitschrift fur Geburtshilfe und Neonatologie': 2,
#          'Gynecologic and obstetric investigation': 2,
#          'Digestion': 1,
#          'Thrombosis research': 2,
#          'Journal of trace elements in medicine and biology : organ of the Society for Minerals and Trace Elements (GMS)': 7,
#          'Stress and health : journal of the International Society for the Investigation of Stress': 1,
#          'Neoplasma': 1,
#          'Photochemical & photobiological sciences : Official journal of the European Photochemistry Association and the European Society for Photobiology': 1,
#          'Clinical psychopharmacology and neuroscience : the official scientific journal of the Korean College of Neuropsychopharmacology': 2,
#          'Disease models & mechanisms': 3,
#          'Diabetes, metabolic syndrome and obesity : targets and therapy': 4,
#          'Non-coding RNA research': 1,
#          'The Turkish journal of gastroenterology : the official journal of Turkish Society of Gastroenterology': 2,
#          ...})

# %%
# getting directly from the pandas package
top_journals_df = records_dataframes["Journal"].value_counts()
# Out:
# International journal of molecular sciences                                                                   313
# Frontiers in immunology                                                                                       304
# Frontiers in pharmacology                                                                                     213
# Evidence-based complementary and alternative medicine : eCAM                                                  171
# Scientific reports                                                                                            141
#                                                                                                              ...
# The Journal of toxicological sciences                                                                           1
# Journal of cell science                                                                                         1
# The Journal of pharmacy technology : jPT : official publication of the Association of Pharmacy Technicians      1
# Animal cells and systems                                                                                        1
# Klinicka onkologie : casopis Ceske a Slovenske onkologicke spolecnosti                                          1
# Name: Journal, Length: 2039, dtype: int64

# %%
# task evaluate it using your own function !
journals_list = records_dataframes["Journal"].tolist()
def counter(record_list, dataframe = False):
    """
    Function to count the occurence of each word
    args:
        record_list type(list) <- list that holds the words to count
        dataframe (bool) <- true if converted into pd.Series
    returns
        dict or series
    """
    counter_journals = {}
    for i in record_list:
        # check the base state
        if i not in counter_journals: 
            # can also used the keys methods here
            counter_journals.update({i:1})
        else:
            counter_journals[i] += 1
            
    if dataframe:
        counter_dataframe = pd.Series(counter_journals).sort_values(ascending = False)
        return counter_dataframe
    return counter_journals

journal_dict = counter(journals_list)
journal_dataframe = counter(journals_list, dataframe = True)

# %%
# Question: How can we calculate from this the percentage?
frequency_dataframe = pd.DataFrame(journal_dataframe, columns = ["count"])
# Answer:
frequency_dataframe["frequency"] = (frequency_dataframe["count"]/ frequency_dataframe["count"].sum()) * 100
# Out:
# 9926

# %%
# Repurpose counter function for word frequency?
# thats why writing function/class methods is important
# We reduce workload, error rates and increase efficency
# Let's look at the Table for the abstracts
def records_tolist(records: list, preprocessed = False, stopwords: list = False) -> pd.Series:
    """ 
    Of importance here is that you understand what you are doing 
    Functions are available gettting rid of stopwords 
    Removing Punctuations
    Introducing Lemmtization and more 
    Which is all important for NLP
    
    args:
        records type(list of lists) <- holds the word records
        stopwords(list) <- default None, holds the 
    """
    if preprocessed:
        record_flatten = records
        
    else:
        record_flatten = [i.replace("(", "").replace(")","").split(" ") for i in records.tolist()]
        
    if stopwords:
        # check if is in stopword
        record_flatten = [t.lower() for i in record_flatten for t in i]
        record_flatten = [i for i in record_flatten if i not in stopwords]
        
    else:    
        #not removing stopwords
        record_flatten = [t for i in record_flatten for t in i]
        
    word_series = counter(record_flatten, dataframe = True)
    return word_series

word_series = records_tolist(records_dataframes["abstract"])
word_series.iloc[1:20]
# Out:
# the             103507
# of               95868
# in               64368
# to               35849
# with             29827
# were             27881
# a                24847
# was              21892
# by               18071
# The              17841
# that             15945
# for              14973
# is               12403
# as               11751
# on               11038
# levels           11034
# expression        9331
# patients          8894
# inflammatory      8772
# dtype: int64

# %%
def preprocessing_list(liste,stopword_list):
    """ 
    preprocess the abstract list, remove stopwords, punctuations, numbers
    input: 
    liste: list of abstracts
    stopword_list: list of stopwords
    returns list of list <- holding the abstracts
    """
    processed_abstracts = []
    for i in liste:
        CUSTOM_FILTERS = [lambda x: x.lower(),remove_stopwords]
        a = preprocess_string(i, CUSTOM_FILTERS)
        no_integers = [x for x in a if not (x.isdigit() or x[0] == '-' and x[1:].isdigit())]
        no_integers = [x for x in no_integers if x not in stopword_list]
        no_integers = [re.sub("[^A-Za-z0-9|-]","",x) for x in no_integers]
        processed_abstracts.append(no_integers)
    return processed_abstracts

# %%
# Self created list of stopwords
# Usually not the way to go, but to gain understanding of how to process the data
stopwords = ["the","of","in","to",
             "with","were","a","was",
             "by","the", "the","that",
             "for","is","as","on","significant",
             "among","although","especially","kg",
             "km","mainly","ml","mm",
             "disease","significantly","obtained","mutation",
             "significant","quite","result","results","estimated",
             "interesting","conducted","associated","performed",
             "respectively","larger","genes","gene", "mutations",
             "related","expression","pattern","mutation","clc","identified",
             "suprisingly","preferentially","subsequently","far","little",
             "known","importantly","synonymous","skipping","father",
             "mother","pedigree","novo","rescues","rescued","restored",
             "exhibits","induce", "Background","Objective","Methods",
             "cells", "kinase","activation","protein",
             "be","at", "we", "p","from","or","after","treatment",
             "=", "are",".", "an"
            ]
word_series_no_stop = records_tolist(records_dataframes["abstract"], stopwords = stopwords)
word_series_no_stop.iloc[1:20]
# Out:
# levels          11154
# patients         9518
# inflammatory     9020
# this             8715
# il-6             7990
# group            7367
# study            6840
# il-6,            6211
# increased        5999
# cell             5515
# effects          4848
# which            4836
# showed           4679
# compared         4506
# serum            4395
# between          4301
# effect           4281
# cytokines        4178
# inflammation     4159
# dtype: int64

# %%
#Check with preprocessing
records_dataframes["processed_abstract"] = preprocessing_list(records_dataframes["abstract"].tolist(),stopwords)
word_series_prep = records_tolist(records_dataframes["processed_abstract"], True, stopwords = stopwords)
word_series_prep[:20]
# Out:
# il-6            14895
# levels          12697
# patients        11913
# group           11297
# study            9241
# inflammatory     9075
#                  7251
# tnf-alpha        6582
# increased        6406
# mice             6317
# inflammation     6023
# effects          5635
# cell             5571
# cytokines        5452
# serum            4685
# showed           4684
# effect           4623
# compared         4609
# il-1beta         4375
# model            4082
# dtype: int64
