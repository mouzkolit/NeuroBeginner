# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# this is called a constant in python 
# PEP-8 says you are not allowed to change also ofc it is possible
iv_condition = pd.read_csv("../Data/Electrophysiology/IV/Processed_Files/iv_condition.csv")
iv_condition.head()
# here we check the first 5 rows of the table
# Out:
#    Unnamed: 0  Sweep #  Voltage2[V]    Ipp_bas[A]    Ipp_beg[A]    Ipp_end[A]  \
# 0           0        1       -0.060  2.560000e-13  8.310000e-13  1.100000e-13
# 1           1        2       -0.055  1.720000e-12  1.020000e-12  5.580000e-13
# 2           2        3       -0.050  7.170000e-14 -8.860000e-13  6.500000e-13
# 3           3        4       -0.045 -7.220000e-13  2.270000e-12 -5.690000e-13
# 4           4        5       -0.040 -1.830000e-12 -1.410000e-12 -1.880000e-12
#
#        Ipeak[A]       Isus[A]       Imax[A]    Max_end[A]  t_peak[s]  \
# 0 -7.500000e-13  2.620000e-12  3.200000e-11  4.140000e-11    0.01990
# 1 -1.160000e-12  3.690000e-12  2.850000e-11  2.790000e-11    0.00165
# 2 -5.920000e-12  1.410000e-11  4.500000e-11  4.310000e-11    0.00765
# 3 -2.620000e-11  3.290000e-11  7.020000e-11  3.770000e-11    0.00235
# 4 -1.040000e-10  5.770000e-11  1.060000e-10  5.850000e-11    0.00235
#
#        Cslow[F]  Rseries[Ohm] condition
# 0  3.360000e-11     7930000.0        wt
# ...

# %%
iv_condition.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126 entries, 0 to 125
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    126 non-null    int64
#  1   Sweep #       126 non-null    int64
#  2   Voltage2[V]   126 non-null    float64
#  3   Ipp_bas[A]    126 non-null    float64
#  4   Ipp_beg[A]    126 non-null    float64
#  5   Ipp_end[A]    126 non-null    float64
#  6   Ipeak[A]      126 non-null    float64
#  7   Isus[A]       126 non-null    float64
#  8   Imax[A]       126 non-null    float64
#  9   Max_end[A]    126 non-null    float64
#  10  t_peak[s]     126 non-null    float64
#  11  Cslow[F]      126 non-null    float64
#  12  Rseries[Ohm]  126 non-null    float64
#  13  condition     126 non-null    object
# dtypes: float64(11), int64(2), object(1)
# memory usage: 13.9+ KB

# %%
iv_condition.describe()
# Out:
#        Unnamed: 0     Sweep #  Voltage2[V]    Ipp_bas[A]    Ipp_beg[A]  \
# count  126.000000  126.000000   126.000000  1.260000e+02  1.260000e+02
# mean    10.000000   11.000000    -0.010000  2.193310e-13  4.493825e-13
# std      6.079474    6.079474     0.030397  3.055033e-12  7.890080e-12
# min      0.000000    1.000000    -0.060000 -9.350000e-12 -1.620000e-11
# 25%      5.000000    6.000000    -0.035000 -1.265000e-12 -3.805000e-12
# 50%     10.000000   11.000000    -0.010000  2.030000e-13  9.710000e-14
# 75%     15.000000   16.000000     0.015000  1.775000e-12  3.597500e-12
# max     20.000000   21.000000     0.040000  1.100000e-11  3.700000e-11
#
#          Ipp_end[A]      Ipeak[A]       Isus[A]       Imax[A]    Max_end[A]  \
# count  1.260000e+02  1.260000e+02  1.260000e+02  1.260000e+02  1.260000e+02
# mean   1.605532e-13 -6.190982e-09  2.454137e-09  2.621080e-09  3.108024e-10
# std    2.797881e-12  4.735466e-09  3.217948e-09  3.228514e-09  4.568184e-10
# ...

# %%
# how can we access a column in a dataframe?
# change it to a list type or an array type
print(min(iv_condition["Imax[A]"]))
max(iv_condition["Ipeak[A]"])
# Out:
# 2.71e-11
# 5.5e-12

# %%
# how can we access ranges?
iv_condition.iloc[:,-3:]
iv_condition.iloc[1:5,:]
# Out:
#    Unnamed: 0  Sweep #  Voltage2[V]    Ipp_bas[A]    Ipp_beg[A]    Ipp_end[A]  \
# 1           1        2       -0.055  1.720000e-12  1.020000e-12  5.580000e-13
# 2           2        3       -0.050  7.170000e-14 -8.860000e-13  6.500000e-13
# 3           3        4       -0.045 -7.220000e-13  2.270000e-12 -5.690000e-13
# 4           4        5       -0.040 -1.830000e-12 -1.410000e-12 -1.880000e-12
#
#        Ipeak[A]       Isus[A]       Imax[A]    Max_end[A]  t_peak[s]  \
# 1 -1.160000e-12  3.690000e-12  2.850000e-11  2.790000e-11    0.00165
# 2 -5.920000e-12  1.410000e-11  4.500000e-11  4.310000e-11    0.00765
# 3 -2.620000e-11  3.290000e-11  7.020000e-11  3.770000e-11    0.00235
# 4 -1.040000e-10  5.770000e-11  1.060000e-10  5.850000e-11    0.00235
#
#        Cslow[F]  Rseries[Ohm] condition
# 1  3.360000e-11     7930000.0        wt
# 2  3.360000e-11     7930000.0        wt
# 3  3.360000e-11     7930000.0        wt
# 4  3.360000e-11     7930000.0        wt

# %%
# how can we acess columns by name
iv_condition[["Ipeak[A]","Ipp_bas[A]"]]
# there is a second way
iv_condition.loc[:,["Ipeak[A]","Ipp_bas[A]"]]
#this one is especially useful to also select rows by name, if you have nameed them
# Out:
#          Ipeak[A]    Ipp_bas[A]
# 0   -7.500000e-13  2.560000e-13
# 1   -1.160000e-12  1.720000e-12
# 2   -5.920000e-12  7.170000e-14
# 3   -2.620000e-11 -7.220000e-13
# 4   -1.040000e-10 -1.830000e-12
# ..            ...           ...
# 121 -5.130000e-09  2.320000e-12
# 122 -4.510000e-09 -1.810000e-12
# 123 -3.900000e-09 -2.490000e-12
# 124 -3.360000e-09 -8.080000e-13
# 125 -2.820000e-09 -6.100000e-12
#
# [126 rows x 2 columns]

# %%
# how can we change an element
# we can select the specific cell
iv_trial = iv_condition.copy(deep = True)
iv_trial.iloc[1,1] = "hello"
iv_trial
# Out:
#      Unnamed: 0 Sweep #  Voltage2[V]    Ipp_bas[A]    Ipp_beg[A]  \
# 0             0       1       -0.060  2.560000e-13  8.310000e-13
# 1             1   hello       -0.055  1.720000e-12  1.020000e-12
# 2             2       3       -0.050  7.170000e-14 -8.860000e-13
# 3             3       4       -0.045 -7.220000e-13  2.270000e-12
# 4             4       5       -0.040 -1.830000e-12 -1.410000e-12
# ..          ...     ...          ...           ...           ...
# 121          16      17        0.020  2.320000e-12  4.050000e-12
# 122          17      18        0.025 -1.810000e-12  1.830000e-11
# 123          18      19        0.030 -2.490000e-12  1.290000e-12
# 124          19      20        0.035 -8.080000e-13 -5.640000e-12
# 125          20      21        0.040 -6.100000e-12  6.820000e-12
#
#        Ipp_end[A]      Ipeak[A]       Isus[A]       Imax[A]    Max_end[A]  \
# 0    1.100000e-13 -7.500000e-13  2.620000e-12  3.200000e-11  4.140000e-11
# ...

# %%
# how would we set a whole columnn to a single value
# instead we could also add a list, but be aware the list must of equal size as the dataframe
iv_condition["amplifier"] = "HEKA"
iv_condition
# Out:
#      Unnamed: 0  Sweep #  Voltage2[V]    Ipp_bas[A]    Ipp_beg[A]  \
# 0             0        1       -0.060  2.560000e-13  8.310000e-13
# 1             1        2       -0.055  1.720000e-12  1.020000e-12
# 2             2        3       -0.050  7.170000e-14 -8.860000e-13
# 3             3        4       -0.045 -7.220000e-13  2.270000e-12
# 4             4        5       -0.040 -1.830000e-12 -1.410000e-12
# ..          ...      ...          ...           ...           ...
# 121          16       17        0.020  2.320000e-12  4.050000e-12
# 122          17       18        0.025 -1.810000e-12  1.830000e-11
# 123          18       19        0.030 -2.490000e-12  1.290000e-12
# 124          19       20        0.035 -8.080000e-13 -5.640000e-12
# 125          20       21        0.040 -6.100000e-12  6.820000e-12
#
#        Ipp_end[A]      Ipeak[A]       Isus[A]       Imax[A]    Max_end[A]  \
# 0    1.100000e-13 -7.500000e-13  2.620000e-12  3.200000e-11  4.140000e-11
# ...

# %%
# lets use a column and add a newe column based on data
binary_condition = []
for i in iv_condition["condition"].tolist():
    if i == "wt":
        binary_condition.append(0)
    else:
        binary_condition.append(1)

# how can we check if this worked right?
# looking at the list might not be very useful
set(binary_condition)
# Out:
# {0, 1}

# %%
# lets add this column to the dataframe
iv_condition["binary_condition"] = binary_condition
iv_condition
# Out:
#      Unnamed: 0  Sweep #  Voltage2[V]    Ipp_bas[A]    Ipp_beg[A]  \
# 0             0        1       -0.060  2.560000e-13  8.310000e-13
# 1             1        2       -0.055  1.720000e-12  1.020000e-12
# 2             2        3       -0.050  7.170000e-14 -8.860000e-13
# 3             3        4       -0.045 -7.220000e-13  2.270000e-12
# 4             4        5       -0.040 -1.830000e-12 -1.410000e-12
# ..          ...      ...          ...           ...           ...
# 121          16       17        0.020  2.320000e-12  4.050000e-12
# 122          17       18        0.025 -1.810000e-12  1.830000e-11
# 123          18       19        0.030 -2.490000e-12  1.290000e-12
# 124          19       20        0.035 -8.080000e-13 -5.640000e-12
# 125          20       21        0.040 -6.100000e-12  6.820000e-12
#
#        Ipp_end[A]      Ipeak[A]       Isus[A]       Imax[A]    Max_end[A]  \
# 0    1.100000e-13 -7.500000e-13  2.620000e-12  3.200000e-11  4.140000e-11
# ...

# %%
# lets have first look using plotting
# we use seaborn for this
# seaborn is a high level framework that is based on matplotlib
# in matplotlib we have to create a figure first
#what do you notice ?
# can we increase the figure size ?
fig,ax = plt.subplots(figsize = (10,7))
sns.despine()
sns.lineplot(x = "Sweep #", y = "Ipeak[A]", data = iv_condition, color = "black")
#sns.boxplot(x = "Sweep #", y = "Ipeak[A]", data = iv_condition, color = "blue")
#sns.swarmplot(x = "Sweep #", y = "Ipeak[A]", data = iv_condition, color= "black")
sns.lineplot(x = "Sweep #", y = "Isus[A]", data = iv_condition, color = "green")
# Out:
# <AxesSubplot: xlabel='Sweep #', ylabel='Ipeak[A]'>
